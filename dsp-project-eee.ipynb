# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/diagnosis-data/patient_diagnosis.csv
# /kaggle/input/test-data/EP76_N,N,A L U,31,M.wav
# /kaggle/input/test-data/EP93_N,N,P R M,75,M.wav
# /kaggle/input/test-data/BP13_Heart Failure,C,P L L,55,M.wav
# /kaggle/input/test-data/BP23_Lung Fibrosis,Crep,P R L ,50,M.wav
# /kaggle/input/test-data/EP67_heart failure,Crep,P R L ,24,F.wav
# /kaggle/input/test-data/EP79_asthma,E W,A R U,46,M.wav
# /kaggle/input/test-data/BP24_heart failure,Crep,P R L ,76,F.wav
# /kaggle/input/test-data/DP32_N,N,A R L,30,M.wav
# /kaggle/input/test-data/DP83_N,N,A R U,18,F.wav
# /kaggle/input/test-data/EP58_asthma,E W,P L M,40,M.wav
# /kaggle/input/test-data/BP50_N,N,P R L ,27,M.wav
# /kaggle/input/test-data/DP36_pneumonia,Crep,P R M,36,F.wav
# /kaggle/input/test-data/EP21_BRON,Crep,P R L ,20,M.wav
# /kaggle/input/test-data/BP69_pneumonia,Bronchial,P R L ,64,M.wav
# /kaggle/input/test-data/BP16_heart failure,C,P R U,56,M.wav
# /kaggle/input/test-data/EP44_asthma,E W,P R U,40,M.wav
# /kaggle/input/test-data/DP97_Asthma,E W,P R U,24,M.wav
# /kaggle/input/test-data/EP94_N,N,P L L,24,M.wav
# /kaggle/input/test-data/BP109_N,N,P L M,26,M.wav
# /kaggle/input/test-data/DP25_copd,E W,P L L,76,M.wav
# /kaggle/input/test-data/DP105_Lung Fibrosis,Crep,A U R,44,M.wav
# /kaggle/input/test-data/EP64_asthma,E W,P L U,60,M.wav
# /kaggle/input/test-data/BP65_asthma,E W,P R L ,60,F.wav
# /kaggle/input/test-data/BP41_pneumonia,Crep,P R M,51,M.wav
# /kaggle/input/test-data/EP106_Asthma,E W,P L U,45,F.wav
# /kaggle/input/test-data/DP103_N,N,P R U,81,F.wav
# /kaggle/input/test-data/BP38_Asthma,E W,P R M,38,M.wav
# /kaggle/input/test-data/DP4_Heart Failure + Lung Fibrosis ,I C,P L R,72,F.wav
# /kaggle/input/test-data/BP45_heart failure,Crep,P R L ,30,M.wav
# /kaggle/input/test-data/BP110_COPD,E W,P L L,62,M.wav
# /kaggle/input/test-data/EP66_heart failure,Crep,P R L ,43,M.wav
# /kaggle/input/test-data/DP24_heart failure,Crep,P R L ,76,F.wav
# /kaggle/input/test-data/EP52_Lung Fibrosis,Crep,P L L,76,F.wav
# /kaggle/input/test-data/DP107_Asthma,E W,P L U,59,F.wav
# /kaggle/input/test-data/BP37_pneumonia,Crep,A R L,70,F.wav
# /kaggle/input/test-data/EP110_COPD,E W,P L L,62,M.wav
# /kaggle/input/test-data/DP28_BRON,Crep,P L U,68,F.wav
# /kaggle/input/test-data/DP10_Asthma,E W,P R U,59,M.wav
# /kaggle/input/test-data/DP47_asthma,E W,P L M,60,M.wav
# /kaggle/input/test-data/DP84_N,N,A R U,65,F.wav
# /kaggle/input/test-data/EP49_N,N,P R M,21,M.wav
# /kaggle/input/test-data/DP40_heart failure,Crep,A R M,26,M.wav
# /kaggle/input/test-data/BP39_heart failure,Crep,P R L ,67,M.wav
# /kaggle/input/test-data/DP46_asthma,E W,P L U,41,F.wav
# /kaggle/input/test-data/EP82_N,N,P L U,38,M.wav
# /kaggle/input/test-data/EP4_Heart Failure + Lung Fibrosis ,I C,P L R,72,F.wav
# /kaggle/input/test-data/DP55_asthma,E W,P R U,72,F.wav
# /kaggle/input/test-data/EP41_pneumonia,Crep,P R M,51,M.wav
# /kaggle/input/test-data/BP22_BRON,Crep,P R U,24,M.wav
# /kaggle/input/test-data/BP18_pneumonia,C,P R U,57,M.wav
# /kaggle/input/test-data/BP68_asthma,E W,P R L ,21,F.wav
# /kaggle/input/test-data/EP17_COPD,E W,A R M,57,M.wav
# /kaggle/input/test-data/EP26_Lung Fibrosis,Crep,P,90,F.wav
# /kaggle/input/test-data/BP63_COPD,E W,P R L ,58,F.wav
# /kaggle/input/test-data/BP67_heart failure,Crep,P R L ,24,F.wav
# /kaggle/input/test-data/DP13_Heart Failure,C,P L L,55,M.wav
# /kaggle/input/test-data/BP77_Asthma,E W,A R L,40,M.wav
# /kaggle/input/test-data/DP92_N,N,P L L ,43,M.wav
# /kaggle/input/test-data/BP35_Asthma,E W,A R L,38,M.wav
# /kaggle/input/test-data/EP78_Asthma,E W,P R M,20,M.wav
# /kaggle/input/test-data/DP86_N,N,P R U,68,F.wav
# /kaggle/input/test-data/DP109_N,N,P L M,26,M.wav
# /kaggle/input/test-data/DP20_Asthma and lung fibrosis,C,A R M,90,M.wav
# /kaggle/input/test-data/EP3_Asthma,I E W,P L L R,50,F.wav
# /kaggle/input/test-data/EP30_N,N,P R M,18,F.wav
# /kaggle/input/test-data/BP59_heart failure,Crep,P R L ,83,F.wav
# /kaggle/input/test-data/BP4_Heart Failure + Lung Fibrosis ,I C,P L R,72,F.wav
# /kaggle/input/test-data/DP87_N,N,P R M,72,M.wav
# /kaggle/input/test-data/EP85_N,N,A R U,33,M.wav
# /kaggle/input/test-data/DP82_N,N,P L U,38,M.wav
# /kaggle/input/test-data/BP70_N,N,P L U,52,F.wav
# /kaggle/input/test-data/EP57_COPD,E W,P R L ,42,M.wav
# /kaggle/input/test-data/EP99_N,N,P R M,50,M.wav
# /kaggle/input/test-data/DP61_COPD,E W,P R L ,53,M.wav
# /kaggle/input/test-data/DP8_Plueral Effusion,I C B,P L L,70,M.wav
# /kaggle/input/test-data/DP95_N,N,P L M,18,M.wav
# /kaggle/input/test-data/DP85_N,N,A R U,33,M.wav
# /kaggle/input/test-data/BP71_N,N,P R U,36,M.wav
# /kaggle/input/test-data/EP46_asthma,E W,P L U,41,F.wav
# /kaggle/input/test-data/BP81_N,N,P L U,33,M.wav
# /kaggle/input/test-data/BP60_heart failure,Crep,P L L,83,F.wav
# /kaggle/input/test-data/BP106_Asthma,E W,P L U,45,F.wav
# /kaggle/input/test-data/BP93_N,N,P R M,75,M.wav
# /kaggle/input/test-data/EP6_Plueral Effusion,I C B,P L R,81,M.wav
# /kaggle/input/test-data/DP14_Heart Failure,C,A R M,54,M.wav
# /kaggle/input/test-data/EP62_COPD,E W,P L M,53,M.wav
# /kaggle/input/test-data/BP55_asthma,E W,P R U,72,F.wav
# /kaggle/input/test-data/EP101_Asthma,E W,P L M,12,F.wav
# /kaggle/input/test-data/EP108_COPD,E W,P R L ,63,M.wav
# /kaggle/input/test-data/DP56_asthma,E W,P R M,56,F.wav
# /kaggle/input/test-data/DP2_Asthma,E W,P L L R,52,F.wav
# /kaggle/input/test-data/BP53_asthma,E W,P R M,72,F.wav
# /kaggle/input/test-data/DP17_COPD,E W,A R M,57,M.wav
# /kaggle/input/test-data/BP97_Asthma,E W,P R U,24,M.wav
# /kaggle/input/test-data/DP104_Asthma,E W,P L U,45,F.wav
# /kaggle/input/test-data/DP27_asthma,E W,P R M,53,F.wav
# /kaggle/input/test-data/EP43_asthma,E W,P L M,15,M.wav
# /kaggle/input/test-data/DP1_Asthma,I E W,P L L,70,M.wav
# /kaggle/input/test-data/DP68_asthma,E W,P R L ,21,F.wav
# /kaggle/input/test-data/EP56_asthma,E W,P R M,56,F.wav
# /kaggle/input/test-data/DP72_N,N,P R U,24,F.wav
# /kaggle/input/test-data/BP2_Asthma,E W,P L L R,52,F.wav
# /kaggle/input/test-data/EP39_heart failure,Crep,P R L ,67,M.wav
# /kaggle/input/test-data/DP108_COPD,E W,P R L ,63,M.wav
# /kaggle/input/test-data/DP29_heart failure,Crep,P L L,57,M.wav
# /kaggle/input/test-data/EP31_N,N,P L M,27,F.wav
# /kaggle/input/test-data/EP29_heart failure,Crep,P L L,57,M.wav
# /kaggle/input/test-data/DP26_Lung Fibrosis,Crep,P,90,F.wav
# /kaggle/input/test-data/DP22_BRON,Crep,P R U,24,M.wav
# /kaggle/input/test-data/EP7_Heart Failure + COPD,I C E W,P L R,65,M.wav
# /kaggle/input/test-data/EP102_N,N,P L L,41,M.wav
# /kaggle/input/test-data/EP95_N,N,P L M,18,M.wav
# /kaggle/input/test-data/DP73_N,N,P L L,32,M.wav
# /kaggle/input/test-data/BP92_N,N,P L L ,43,M.wav
# /kaggle/input/test-data/BP101_Asthma,E W,P L M,12,F.wav
# /kaggle/input/test-data/EP84_N,N,A R U,65,F.wav
# /kaggle/input/test-data/BP9_Asthma,E W,P R L ,59,M.wav
# /kaggle/input/test-data/BP33_Asthma,E W,P R M,43,F.wav
# /kaggle/input/test-data/EP63_COPD,E W,P R L ,58,F.wav
# /kaggle/input/test-data/DP67_heart failure,Crep,P R L ,24,F.wav
# /kaggle/input/test-data/BP21_BRON,Crep,P R L ,20,M.wav
# /kaggle/input/test-data/DP58_asthma,E W,P L M,40,M.wav
# /kaggle/input/test-data/DP30_N,N,P R M,18,F.wav
# /kaggle/input/test-data/BP12_Asthma,E W,P L L,50,F.wav
# /kaggle/input/test-data/BP26_Lung Fibrosis,Crep,P,90,F.wav
# /kaggle/input/test-data/EP87_N,N,P R M,72,M.wav
# /kaggle/input/test-data/DP6_Plueral Effusion,I C B,P L R,81,M.wav
# /kaggle/input/test-data/DP71_N,N,P R U,36,M.wav
# /kaggle/input/test-data/DP39_heart failure,Crep,P R L ,67,M.wav
# /kaggle/input/test-data/BP44_asthma,E W,P R U,40,M.wav
# /kaggle/input/test-data/DP69_pneumonia,Bronchial,P R L ,64,M.wav
# /kaggle/input/test-data/DP44_asthma,E W,P R U,40,M.wav
# /kaggle/input/test-data/BP20_Asthma and lung fibrosis,C,A R M,90,M.wav
# /kaggle/input/test-data/DP23_Lung Fibrosis,Crep,P R L ,50,M.wav
# /kaggle/input/test-data/EP74_N,N,P R M,74,M.wav
# /kaggle/input/test-data/BP83_N,N,A R U,18,F.wav
# /kaggle/input/test-data/BP74_N,N,P R M,74,M.wav
# /kaggle/input/test-data/BP61_COPD,E W,P R L ,53,M.wav
# /kaggle/input/test-data/DP74_N,N,P R M,74,M.wav
# /kaggle/input/test-data/EP83_N,N,A R U,18,F.wav
# /kaggle/input/test-data/EP37_pneumonia,Crep,A R L,70,F.wav
# /kaggle/input/test-data/EP88_N,N,A R U,29,M.wav
# /kaggle/input/test-data/EP45_heart failure,Crep,P R L ,30,M.wav
# /kaggle/input/test-data/DP19_heart failure,C,P R U,70,F.wav
# /kaggle/input/test-data/DP38_Asthma,E W,P R M,38,M.wav
# /kaggle/input/test-data/DP43_asthma,E W,P L M,15,M.wav
# /kaggle/input/test-data/EP60_heart failure,Crep,P L L,83,F.wav
# /kaggle/input/test-data/DP54_heart failure,Crep,P R L ,73,F.wav
# /kaggle/input/test-data/EP109_N,N,P L M,26,M.wav
# /kaggle/input/test-data/EP61_COPD,E W,P R L ,53,M.wav
# /kaggle/input/test-data/EP59_heart failure,Crep,P R L ,83,F.wav
# /kaggle/input/test-data/BP28_BRON,Crep,P L U,68,F.wav
# /kaggle/input/test-data/BP29_heart failure,Crep,P L L,57,M.wav
# /kaggle/input/test-data/EP72_N,N,P R U,24,F.wav
# /kaggle/input/test-data/EP54_heart failure,Crep,P R L ,73,F.wav
# /kaggle/input/test-data/DP81_N,N,P L U,33,M.wav
# /kaggle/input/test-data/DP34_heart failure,Crep,P R M,78,F.wav
# /kaggle/input/test-data/DP48_N,N,P L U,31,M.wav
# /kaggle/input/test-data/EP20_Asthma and lung fibrosis,C,A R M,90,M.wav
# /kaggle/input/test-data/DP5_Heart Failure + COPD,I C E W,P L R ,71,M.wav
# /kaggle/input/test-data/EP10_Asthma,E W,P R U,59,M.wav
# /kaggle/input/test-data/BP86_N,N,P R U,68,F.wav
# /kaggle/input/test-data/BP64_asthma,E W,P L U,60,M.wav
# /kaggle/input/test-data/EP90_heart failure,Crep,P L M,74,F.wav
# /kaggle/input/test-data/BP85_N,N,A R U,33,M.wav
# /kaggle/input/test-data/BP87_N,N,P R M,72,M.wav
# /kaggle/input/test-data/EP89_N,N,P L M,70,M.wav
# /kaggle/input/test-data/BP99_N,N,P R M,50,M.wav
# /kaggle/input/test-data/EP47_asthma,E W,P L M,60,M.wav
# /kaggle/input/test-data/EP28_BRON,Crep,P L U,68,F.wav
# /kaggle/input/test-data/EP105_Lung Fibrosis,Crep,A U R,44,M.wav
# /kaggle/input/test-data/EP55_asthma,E W,P R U,72,F.wav
# /kaggle/input/test-data/DP64_asthma,E W,P L U,60,M.wav
# /kaggle/input/test-data/EP16_heart failure,C,P R U,56,M.wav
# /kaggle/input/test-data/BP3_Asthma,I E W,P L L R,50,F.wav
# /kaggle/input/test-data/BP51_N,N,P L M,30,M.wav
# /kaggle/input/test-data/DP57_COPD,E W,P R L ,42,M.wav
# /kaggle/input/test-data/EP38_Asthma,E W,P R M,38,M.wav
# /kaggle/input/test-data/EP111_COPD,E W,P R L ,51,M.wav
# /kaggle/input/test-data/DP80_asthma,E W,A L U,38,M.wav
# /kaggle/input/test-data/EP91_asthma,E W,P R U,43,F.wav
# /kaggle/input/test-data/DP33_Asthma,E W,P R M,43,F.wav
# /kaggle/input/test-data/DP110_COPD,E W,P L L,62,M.wav
# /kaggle/input/test-data/DP59_heart failure,Crep,P R L ,83,F.wav
# /kaggle/input/test-data/EP86_N,N,P R U,68,F.wav
# /kaggle/input/test-data/BP84_N,N,A R U,65,F.wav
# /kaggle/input/test-data/EP96_N,N,P R L ,66,F.wav
# /kaggle/input/test-data/EP33_Asthma,E W,P R M,43,F.wav
# /kaggle/input/test-data/BP94_N,N,P L L,24,M.wav
# /kaggle/input/test-data/EP70_N,N,P L U,52,F.wav
# /kaggle/input/test-data/EP32_N,N,A R L,30,M.wav
# /kaggle/input/test-data/DP41_pneumonia,Crep,P R M,51,M.wav
# /kaggle/input/test-data/DP79_asthma,E W,A R U,46,M.wav
# /kaggle/input/test-data/BP95_N,N,P L M,18,M.wav
# /kaggle/input/test-data/EP27_asthma,E W,P R M,53,F.wav
# /kaggle/input/test-data/DP65_asthma,E W,P R L ,60,F.wav
# /kaggle/input/test-data/DP12_Asthma,E W,P L L,50,F.wav
# /kaggle/input/test-data/BP72_N,N,P R U,24,F.wav
# /kaggle/input/test-data/DP15_Asthma,E W,P R U,49,F.wav
# /kaggle/input/test-data/EP75_N,N,P L U,73,F.wav
# /kaggle/input/test-data/BP17_COPD,E W,A R M,57,M.wav
# /kaggle/input/test-data/EP19_heart failure,C,P R U,70,F.wav
# /kaggle/input/test-data/DP42_heart failure,Crep,P L L,56,M.wav
# /kaggle/input/test-data/DP70_N,N,P L U,52,F.wav
# /kaggle/input/test-data/DP112_N,N,P L M,30,M.wav
# /kaggle/input/test-data/DP76_N,N,A L U,31,M.wav
# /kaggle/input/test-data/DP45_heart failure,Crep,P R L ,30,M.wav
# /kaggle/input/test-data/EP73_N,N,P L L,32,M.wav
# /kaggle/input/test-data/BP27_asthma,E W,P R M,53,F.wav
# /kaggle/input/test-data/EP69_pneumonia,Bronchial,P R L ,64,M.wav
# /kaggle/input/test-data/BP36_pneumonia,Crep,P R M,36,F.wav
# /kaggle/input/test-data/BP19_heart failure,C,P R U,70,F.wav
# /kaggle/input/test-data/EP92_N,N,P L L ,43,M.wav
# /kaggle/input/test-data/DP53_asthma,E W,P R M,72,F.wav
# /kaggle/input/test-data/EP25_copd,E W,P L L,76,M.wav
# /kaggle/input/test-data/DP37_pneumonia,Crep,A R L,70,F.wav
# /kaggle/input/test-data/DP9_Asthma,E W,P R L ,59,M.wav
# /kaggle/input/test-data/BP11_Heart Failure,C,P L L,53,M.wav
# /kaggle/input/test-data/EP104_Asthma,E W,P L U,45,F.wav
# /kaggle/input/test-data/BP5_Heart Failure + COPD,I C E W,P L R ,71,M.wav
# /kaggle/input/test-data/BP88_N,N,A R U,29,M.wav
# /kaggle/input/test-data/DP93_N,N,P R M,75,M.wav
# /kaggle/input/test-data/BP66_heart failure,Crep,P R L ,43,M.wav
# /kaggle/input/test-data/BP58_asthma,E W,P L M,40,M.wav
# /kaggle/input/test-data/DP77_Asthma,E W,A R L,40,M.wav
# /kaggle/input/test-data/EP8_Plueral Effusion,I C B,P L L,70,M.wav
# /kaggle/input/test-data/BP52_Lung Fibrosis,Crep,P L L,76,F.wav
# /kaggle/input/test-data/BP40_heart failure,Crep,A R M,26,M.wav
# /kaggle/input/test-data/BP31_N,N,P L M,27,F.wav
# /kaggle/input/test-data/EP36_pneumonia,Crep,P R M,36,F.wav
# /kaggle/input/test-data/BP15_Asthma,E W,P R U,49,F.wav
# /kaggle/input/test-data/BP73_N,N,P L L,32,M.wav
# /kaggle/input/test-data/EP71_N,N,P R U,36,M.wav
# /kaggle/input/test-data/BP105_Lung Fibrosis,Crep,A U R,44,M.wav
# /kaggle/input/test-data/EP51_N,N,P L M,30,M.wav
# /kaggle/input/test-data/EP42_heart failure,Crep,P L L,56,M.wav
# /kaggle/input/test-data/BP89_N,N,P L M,70,M.wav
# /kaggle/input/test-data/BP56_asthma,E W,P R M,56,F.wav
# /kaggle/input/test-data/BP108_COPD,E W,P R L ,63,M.wav
# /kaggle/input/test-data/DP106_Asthma,E W,P L U,45,F.wav
# /kaggle/input/test-data/EP5_Heart Failure + COPD,I C E W,P L R ,71,M.wav
# /kaggle/input/test-data/BP14_Heart Failure,C,A R M,54,M.wav
# /kaggle/input/test-data/EP103_N,N,P R U,81,F.wav
# /kaggle/input/test-data/DP62_COPD,E W,P L M,53,M.wav
# /kaggle/input/test-data/DP91_asthma,E W,P R U,43,F.wav
# /kaggle/input/test-data/BP25_copd,E W,P L L,76,M.wav
# /kaggle/input/test-data/BP98_N,N,P L L,53,M.wav
# /kaggle/input/test-data/BP104_Asthma,E W,P L U,45,F.wav
# /kaggle/input/test-data/BP103_N,N,P R U,81,F.wav
# /kaggle/input/test-data/BP57_COPD,E W,P R L ,42,M.wav
# /kaggle/input/test-data/EP40_heart failure,Crep,A R M,26,M.wav
# /kaggle/input/test-data/EP18_pneumonia,C,P R U,57,M.wav
# /kaggle/input/test-data/EP23_Lung Fibrosis,Crep,P R L ,50,M.wav
# /kaggle/input/test-data/EP77_Asthma,E W,A R L,40,M.wav
# /kaggle/input/test-data/EP100_N,N,P R M,70,F.wav
# /kaggle/input/test-data/DP90_heart failure,Crep,P L M,74,F.wav
# /kaggle/input/test-data/DP101_Asthma,E W,P L M,12,F.wav
# /kaggle/input/test-data/DP60_heart failure,Crep,P L L,83,F.wav
# /kaggle/input/test-data/EP107_Asthma,E W,P L U,59,F.wav
# /kaggle/input/test-data/DP51_N,N,P L M,30,M.wav
# /kaggle/input/test-data/EP48_N,N,P L U,31,M.wav
# /kaggle/input/test-data/BP46_asthma,E W,P L U,41,F.wav
# /kaggle/input/test-data/EP35_Asthma,E W,A R L,38,M.wav
# /kaggle/input/test-data/BP82_N,N,P L U,38,M.wav
# /kaggle/input/test-data/DP63_COPD,E W,P R L ,58,F.wav
# /kaggle/input/test-data/BP102_N,N,P L L,41,M.wav
# /kaggle/input/test-data/BP96_N,N,P R L ,66,F.wav
# /kaggle/input/test-data/DP31_N,N,P L M,27,F.wav
# /kaggle/input/test-data/BP75_N,N,P L U,73,F.wav
# /kaggle/input/test-data/DP18_pneumonia,C,P R U,57,M.wav
# /kaggle/input/test-data/EP68_asthma,E W,P R L ,21,F.wav
# /kaggle/input/test-data/BP107_Asthma,E W,P L U,59,F.wav
# /kaggle/input/test-data/EP15_Asthma,E W,P R U,49,F.wav
# /kaggle/input/test-data/BP80_asthma,E W,A L U,38,M.wav
# /kaggle/input/test-data/DP16_heart failure,C,P R U,56,M.wav
# /kaggle/input/test-data/DP50_N,N,P R L ,27,M.wav
# /kaggle/input/test-data/EP98_N,N,P L L,53,M.wav
# /kaggle/input/test-data/DP49_N,N,P R M,21,M.wav
# /kaggle/input/test-data/DP11_Heart Failure,C,P L L,53,M.wav
# /kaggle/input/test-data/DP100_N,N,P R M,70,F.wav
# /kaggle/input/test-data/DP21_BRON,Crep,P R L ,20,M.wav
# /kaggle/input/test-data/DP75_N,N,P L U,73,F.wav
# /kaggle/input/test-data/EP65_asthma,E W,P R L ,60,F.wav
# /kaggle/input/test-data/EP2_Asthma,E W,P L L R,52,F.wav
# /kaggle/input/test-data/DP96_N,N,P R L ,66,F.wav
# /kaggle/input/test-data/DP94_N,N,P L L,24,M.wav
# /kaggle/input/test-data/EP34_heart failure,Crep,P R M,78,F.wav
# /kaggle/input/test-data/DP7_Heart Failure + COPD,I C E W,P L R,65,M.wav
# /kaggle/input/test-data/EP9_Asthma,E W,P R L ,59,M.wav
# /kaggle/input/test-data/DP99_N,N,P R M,50,M.wav
# /kaggle/input/test-data/DP3_Asthma,I E W,P L L R,50,F.wav
# /kaggle/input/test-data/BP47_asthma,E W,P L M,60,M.wav
# /kaggle/input/test-data/BP91_asthma,E W,P R U,43,F.wav
# /kaggle/input/test-data/EP11_Heart Failure,C,P L L,53,M.wav
# /kaggle/input/test-data/EP50_N,N,P R L ,27,M.wav
# /kaggle/input/test-data/EP80_asthma,E W,A L U,38,M.wav
# /kaggle/input/test-data/BP7_Heart Failure + COPD,I C E W,P L R,65,M.wav
# /kaggle/input/test-data/BP79_asthma,E W,A R U,46,M.wav
# /kaggle/input/test-data/BP90_heart failure,Crep,P L M,74,F.wav
# /kaggle/input/test-data/DP78_Asthma,E W,P R M,20,M.wav
# /kaggle/input/test-data/EP14_Heart Failure,C,A R M,54,M.wav
# /kaggle/input/test-data/DP89_N,N,P L M,70,M.wav
# /kaggle/input/test-data/BP62_COPD,E W,P L M,53,M.wav
# /kaggle/input/test-data/BP100_N,N,P R M,70,F.wav
# /kaggle/input/test-data/BP78_Asthma,E W,P R M,20,M.wav
# /kaggle/input/test-data/DP66_heart failure,Crep,P R L ,43,M.wav
# /kaggle/input/test-data/EP1_Asthma,I E W,P L L,70,M.wav
# /kaggle/input/test-data/EP22_BRON,Crep,P R U,24,M.wav
# /kaggle/input/test-data/BP10_Asthma,E W,P R U,59,M.wav
# /kaggle/input/test-data/BP1_Asthma,I E W,P L L,70,M.wav
# /kaggle/input/test-data/BP49_N,N,P R M,21,M.wav
# /kaggle/input/test-data/EP13_Heart Failure,C,P L L,55,M.wav
# /kaggle/input/test-data/DP52_Lung Fibrosis,Crep,P L L,76,F.wav
# /kaggle/input/test-data/BP111_COPD,E W,P R L ,51,M.wav
# /kaggle/input/test-data/DP35_Asthma,E W,A R L,38,M.wav
# /kaggle/input/test-data/BP76_N,N,A L U,31,M.wav
# /kaggle/input/test-data/BP43_asthma,E W,P L M,15,M.wav
# /kaggle/input/test-data/BP34_heart failure,Crep,P R M,78,F.wav
# /kaggle/input/test-data/BP42_heart failure,Crep,P L L,56,M.wav
# /kaggle/input/test-data/BP6_Plueral Effusion,I C B,P L R,81,M.wav
# /kaggle/input/test-data/BP8_Plueral Effusion,I C B,P L L,70,M.wav
# /kaggle/input/test-data/EP24_heart failure,Crep,P R L ,76,F.wav
# /kaggle/input/test-data/DP98_N,N,P L L,53,M.wav
# /kaggle/input/test-data/EP53_asthma,E W,P R M,72,F.wav
# /kaggle/input/test-data/BP54_heart failure,Crep,P R L ,73,F.wav
# /kaggle/input/test-data/EP112_N,N,P L M,30,M.wav
# /kaggle/input/test-data/BP112_N,N,P L M,30,M.wav
# /kaggle/input/test-data/EP12_Asthma,E W,P L L,50,F.wav
# /kaggle/input/test-data/BP48_N,N,P L U,31,M.wav
# /kaggle/input/test-data/DP88_N,N,A R U,29,M.wav
# /kaggle/input/test-data/DP102_N,N,P L L,41,M.wav
# /kaggle/input/test-data/DP111_COPD,E W,P R L ,51,M.wav
# /kaggle/input/test-data/BP30_N,N,P R M,18,F.wav
# /kaggle/input/test-data/BP32_N,N,A R L,30,M.wav
# /kaggle/input/test-data/EP97_Asthma,E W,P R U,24,M.wav
# /kaggle/input/test-data/EP81_N,N,P L U,33,M.wav
# /kaggle/input/dsp-project/Seperated files/txt files/168_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3p2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_2b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2p5_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/109_1b1_Pr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_2b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/102_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1p3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/156_8b3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_1p2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/202_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p4_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b5_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/193_7b3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_2p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/160_2b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/199_2b3_Ll_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b5_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_1p3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_1p3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/195_1b1_Lr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/174_2p3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_2b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/200_3p4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/188_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/200_2p4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/115_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/186_3b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/114_1b4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/222_1b1_Lr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_1b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_1b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_2b2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/124_1b1_Lr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/135_2b1_Tc_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/174_1p2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/116_1b2_Pl_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_2b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/104_1b1_Pl_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/193_1b2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/160_2b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/124_1b1_Ll_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/135_2b3_Pl_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/185_1b1_Pl_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/222_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/218_1b1_Pl_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_2b5_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_1p3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/203_2p3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/148_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/186_3b3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/193_7b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/194_1b1_Lr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_2b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/113_1b1_Ar_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/108_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/109_1b1_Al_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/118_1b1_Ll_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/184_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/223_1b1_Lr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_2b5_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/186_2b2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_3p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/146_8p3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_1p3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b6_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1p3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/160_1b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_3p2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_1p5_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/112_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/204_7p5_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/210_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/206_1b1_Pl_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/200_3p4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/197_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/204_2b5_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/219_2b2_Ar_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/118_1b1_Pl_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/216_1b1_Pl_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/169_1b1_Lr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_1p4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/205_1b3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/203_1p3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/145_3b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/150_1b2_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2b4_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b5_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/205_3b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/204_7p5_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/125_1b1_Tc_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/135_2b3_Al_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_2b4_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_1b4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_1p2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/186_2b4_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/154_4b4_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/205_4b2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/160_1b3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/181_1b2_Ar_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p4_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/109_1b1_Ar_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_3p4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/155_2b1_Al_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/222_1b1_Pr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_2b2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b5_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b4_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_2p2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/181_1b3_Tc_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_2p2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/200_2p3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/195_1b1_Ar_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_1p2_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b5_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_2p4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_3p2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/193_7b3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/203_2p3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/129_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_2b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_2p2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/109_1b1_Ll_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1p2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_1p4_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3b4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/146_8p3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/167_1b1_Pr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/146_2b4_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2p3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/120_1b1_Lr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_2b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/139_1b1_Ar_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3p3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/139_1b1_Pr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/122_2b3_Al_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b6_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b5_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/175_1b1_Ll_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/139_1b1_Pl_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/205_4b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_2b5_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/156_5b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2b2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_1b4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/174_1p3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/154_1b3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_2b2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_1p4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_1b4_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/104_1b1_Pr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_1b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b5_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/204_7p5_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/223_1b1_Pl_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/146_2b2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/205_1b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1p3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/112_1p1_Ll_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1p2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/140_2b3_Tc_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/203_1p4_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/160_1b4_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_2p3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/162_1b2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2b2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_2p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1p4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/142_1b1_Pl_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_2b3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/183_1b1_Pl_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3b4_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/180_1b4_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/160_1b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/124_1b1_Ar_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/173_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/198_6p1_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/205_3b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/160_1b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_1p5_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b6_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_2b2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/113_1b1_Al_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/165_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/182_1b1_Tc_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_2b5_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/220_1b2_Al_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/215_1b2_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/144_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/154_2b4_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_2b2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_1p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/118_1b1_Pr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/219_2b3_Tc_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/166_1p1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/110_1b1_Pr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/203_2p3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/224_1b2_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/181_1b1_Tc_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/195_1b1_Pr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/134_2b1_Al_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_2p3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b6_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2b3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/152_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/203_1p3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b5_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/186_3b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/162_2b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_2b4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_1p2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_1p5_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/156_2b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/154_2b4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/200_2p4_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/154_3b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/113_1b1_Pr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_3p2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/192_2b1_Ar_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_2b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/221_2b1_Al_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1p2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/199_2b1_Ll_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/218_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/156_8b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_3p2_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_3b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3p4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_1b3_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/113_1b1_Ll_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_1p2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/131_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/214_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/162_2b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_2b5_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/145_2b2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1p4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/200_2p2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_1b4_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/178_1b6_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_2b4_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/226_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/146_8p3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/191_2b1_Pl_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/226_1b1_Ll_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/169_1b2_Ll_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_1b2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/154_2b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/170_1b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_3p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/203_1p3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_1p2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3b4_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/163_8b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_2p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/149_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_2b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/135_2b1_Pl_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/177_2b4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_2b2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/186_3b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/223_1b1_Ll_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/174_1p3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b4_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/156_2b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_1p2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/204_7p5_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/110_1p1_Pr_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_1p2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_1b3_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_1b4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/176_1b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/154_4b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/204_7p5_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/203_1p2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b5_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/198_6p1_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_3p2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/130_1p4_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/205_4b2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/132_2b1_Lr_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/122_2b3_Tc_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/186_2b4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/192_2b2_Ar_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/158_1b3_Ar_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/141_1b3_Al_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/186_2b3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/213_2p2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/221_2b3_Pr_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/200_2p2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_1p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/210_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_1b2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_2p2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/211_1p2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_3p2_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/145_2b2_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/147_1b4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/104_1b1_Lr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/141_1b2_Lr_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/124_1b1_Pr_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/174_1p3_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/205_2b3_Ll_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/146_8p3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/134_2b1_Ar_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_2p4_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/180_1b4_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/122_2b3_Ar_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/212_2b2_Tc_mc_LittC2SE.txt
# /kaggle/input/dsp-project/Seperated files/txt files/114_1b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/121_1p1_Tc_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/145_3b2_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/195_1b1_Ll_sc_Litt3200.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/172_1b3_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/107_2b4_Ar_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/133_3p2_Pr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/138_1p3_Lr_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/126_1b1_Al_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/151_2p4_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/208_1b1_Ll_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/207_2b2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/224_1b1_Tc_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/119_1b1_Ar_sc_Meditron.txt
# /kaggle/input/dsp-project/Seperated files/txt files/174_1p2_Tc_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/200_2p2_Pl_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/162_2b3_Al_mc_AKGC417L.txt
# /kaggle/input/dsp-project/Seperated files/txt files/110_1p1_Lr_sc_Meditron.txt
# ...
# /kaggle/input/dsp-project/Seperated files/audio files/116_1b2_Pl_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/198_1b5_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/174_1p3_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/110_1p1_Al_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/162_2b3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/120_1b1_Al_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/172_1b3_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/225_1b1_Pl_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/224_1b2_Al_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/201_1b1_Al_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/135_2b3_Tc_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/158_1p2_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/203_1p3_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/198_1b5_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/147_1b4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/172_1b5_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/172_2b5_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/144_1b1_Tc_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/162_2b3_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/174_2p3_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/221_2b3_Al_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_3b4_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/174_1p3_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/135_2b3_Pl_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/200_2p2_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/156_2b3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/207_2b4_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/204_7p5_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/174_1p2_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/160_1b2_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/200_2p4_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/200_2p2_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/219_2b1_Tc_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_1p4_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/195_1b1_Ar_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/138_1p3_Ll_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/177_2b4_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/146_8p3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/200_3p4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/203_1p2_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/174_2p3_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/198_1b5_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_1p4_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/138_2p2_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/163_2b2_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_2b3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/157_1b1_Ar_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/163_8b3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_2b4_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/154_3b3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/135_2b1_Pl_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/206_1b1_Pl_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/112_1b1_Ar_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/129_1b1_Ar_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/156_2b3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/160_1b3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/176_1b4_Ll_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/224_1b1_Tc_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/133_3p2_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/207_3b2_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_1p2_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/223_1b1_Lr_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/138_1p4_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/170_1b2_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/154_1b3_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/178_1b6_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/158_2p3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/160_1b4_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/105_1b1_Tc_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/104_1b1_Pl_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/133_3p2_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/204_2b5_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/207_3b2_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/186_2b3_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/108_1b1_Al_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/138_1p3_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/174_1p4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/124_1b1_Lr_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/158_1p4_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/205_2b4_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_2p5_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/177_2b4_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_3p4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/170_2b2_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/170_2b2_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/154_2b4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/195_1b1_Al_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/203_1p4_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/162_1b2_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/151_3p2_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/213_1p3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/170_1b2_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/177_1b4_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/168_1b1_Al_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/162_2b4_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/158_1p2_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/199_2b1_Ll_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/188_1b1_Al_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/137_1b1_Ll_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/218_1p1_Pr_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/205_1b3_Ll_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/117_1b2_Tc_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/195_1b1_Ll_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/212_2b2_Tc_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/207_2b3_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_1p3_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/192_2b2_Ar_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/114_1b4_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/160_1b2_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/205_2b3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/172_1b4_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/118_1b1_Pr_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/175_1b1_Pl_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/107_2b5_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_1p3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/138_1p3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/163_8b3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/213_1p5_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/205_4b2_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/160_1b3_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/175_1b1_Al_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/133_2p3_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/138_1p3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/114_1b4_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/181_1b2_Ar_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/170_1b4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_2b3_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/133_2p4_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/162_2b2_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_2b2_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/180_1b4_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/157_1b1_Pl_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/146_2b4_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/220_1b1_Tc_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/176_2b3_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/176_1b4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/122_2b3_Al_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/205_4b2_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/205_3b4_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/213_1p5_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/147_2b4_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/109_1b1_Pr_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/170_1b2_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/174_1p2_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/205_1b3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/207_3b2_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/146_2b2_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/204_7p5_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/178_1b2_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/195_1b1_Lr_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_3p3_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/200_3p4_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/126_1b1_Al_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/186_2b3_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/156_5b3_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/151_2p2_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/140_2b2_Tc_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/104_1b1_Al_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_3b4_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/158_1p4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/186_2b2_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/178_1b6_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/178_2b2_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/145_2b2_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/107_3p2_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/159_1b1_Pr_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/162_2b4_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/220_1b2_Al_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/133_2p4_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_2p5_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/155_2b1_Al_mc_LittC2SE.wav
# /kaggle/input/dsp-project/Seperated files/audio files/200_3p4_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/149_1b1_Pl_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_2p5_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/184_1b1_Ar_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/162_2b4_Tc_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/175_1b1_Lr_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/186_2b4_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/207_2b4_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/102_1b1_Ar_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/156_2b3_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/118_1b1_Al_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/151_2p4_Pr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/170_1b3_Ll_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/104_1b1_Ar_sc_Litt3200.wav
# /kaggle/input/dsp-project/Seperated files/audio files/160_2b4_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_2p5_Lr_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/178_1b3_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/178_1b6_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/130_3p3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/107_2b3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/147_2b3_Pl_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/162_2b4_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/186_2b3_Ar_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/111_1b3_Tc_sc_Meditron.wav
# /kaggle/input/dsp-project/Seperated files/audio files/151_2p3_Al_mc_AKGC417L.wav
# /kaggle/input/dsp-project/Seperated files/audio files/170_1b4_Pl_mc_AKGC417L.wav

# %%
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

# %%
def preprocess_audio(file_path, target_duration=5.0, sr=22050):
    """
    Preprocesses the audio file:
    - Trims or pads to a fixed duration.
    - Focuses on respiratory cycles with crackles/wheezes.
    """
    # Load the audio
    audio, _ = librosa.load(file_path, sr=sr)
    
    # Trim silence
    audio, _ = librosa.effects.trim(audio)
    
    # Pad or truncate to target duration
    target_samples = int(target_duration * sr)
    if len(audio) > target_samples:
        audio = audio[:target_samples]
    elif len(audio) < target_samples:
        audio = np.pad(audio, (0, target_samples - len(audio)), 'constant')
    
    return audio

# %%
def extract_features(audio, sr=22050):
    """
    Extract multiple audio features:
    - Mel-frequency cepstral coefficients (MFCCs)
    - Zero-crossing rate (ZCR)
    - Chroma feature
    - Spectral contrast
    """
    try:
        # Compute MFCCs
        mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13).T, axis=0)
        # Compute zero-crossing rate
        zcr = np.mean(librosa.feature.zero_crossing_rate(y=audio))
        # Compute chroma features
        chroma = np.mean(librosa.feature.chroma_stft(y=audio, sr=sr).T, axis=0)
        # Compute spectral contrast
        spectral_contrast = np.mean(librosa.feature.spectral_contrast(y=audio, sr=sr).T, axis=0)
        
        return np.concatenate([mfccs, [zcr], chroma, spectral_contrast])
    except Exception as e:
        print(f"Feature extraction error: {e}")
        return None

# %%
def parse_annotations(annotation_file):
    """
    Parse annotations to identify respiratory cycles with crackles/wheezes.
    """
    data = pd.read_csv(annotation_file, sep='\s+', header=None, 
                       names=["start", "end", "crackles", "wheezes"])
    if data.empty:
        return None, None
    return data["crackles"].sum(), data["wheezes"].sum()

# %%
def main_pipeline(audio_dir, annotation_dir, diagnosis_file):
    # Load the diagnosis data
    diagnosis_df = pd.read_csv(diagnosis_file)
    
    features, labels = [], []
    
    for file in os.listdir(audio_dir):
        if file.endswith(".wav"):
            audio_file = os.path.join(audio_dir, file)
            annotation_file = os.path.join(annotation_dir, f"{os.path.splitext(file)[0]}.txt")
            
            if not os.path.exists(annotation_file):
                print(f"Annotation file missing for {file}, skipping...")
                continue
            try:
                # Preprocess audio
                audio = preprocess_audio(audio_file)
                
                # Extract features
                feature = extract_features(audio)

                # Parse annotation
                crackles, wheezes = parse_annotations(annotation_file)
                if crackles is None or wheezes is None:
                    print(f"No valid annotations for {file}, skipping...")
                    continue
                # Get the patient ID and diagnosis
                patient_id = file.split('_')[0]  # Assuming patient ID is the prefix
                diagnosis = diagnosis_df.loc[diagnosis_df["Patient ID"] == int(patient_id), "Diagnosis"]
                if diagnosis.empty:
                    print(f"No diagnosis found for {file}, skipping...")
                    continue
                
                # Store features and labels
                features.append(feature)
                labels.append(diagnosis.values[0])
            except Exception as e:
                print(f"Error processing {file}: {e}")
                continue
    
    return np.array(features), np.array(labels)

# %%
# Train and classify
def classify(features, labels):
    """
    Train RandomForestClassifier and evaluate on test data.
    """
    le = LabelEncoder()
    labels = le.fit_transform(labels)
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
    
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    clf = RandomForestClassifier(n_estimators=100, random_state=42)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    
    # Adjust the target_names to match only those present in y_test
    unique_classes = np.unique(y_test)  # Classes actually in the test set
    target_names = [le.classes_[i] for i in unique_classes]
    
    print("Classification Report:")
    print(classification_report(y_test, y_pred, labels=unique_classes, target_names=target_names))
    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
    
    return clf, scaler, le

# %%
def predict_new_file(clf, scaler, le, audio_path):
    """
    Predicts the diagnosis for a given audio file.
    """
    audio = preprocess_audio(audio_path)
    feature = extract_features(audio).reshape(1, -1)
    feature = scaler.transform(feature)
    prediction = clf.predict(feature)
    return le.inverse_transform(prediction)

# %%
import joblib

def save_model(clf, scaler, le, model_path="/kaggle/working/lung_disease_model.joblib"):
    """
    Save the trained model, scaler, and label encoder to a file.
    """
    model_data = {
        "classifier": clf,
        "scaler": scaler,
        "label_encoder": le
    }
    joblib.dump(model_data, model_path)
    print(f"Model saved to {model_path}")

# %%
if __name__ == "__main__":
    AUDIO_DIR = "/kaggle/input/dsp-project/Seperated files/audio files"  # Update with actual path
    ANNOTATION_DIR = "/kaggle/input/dsp-project/Seperated files/txt files"  # Update with actual path
    DIAGNOSIS_FILE = "/kaggle/input/diagnosis-data/patient_diagnosis.csv"
    
    features, labels = main_pipeline(AUDIO_DIR, ANNOTATION_DIR, DIAGNOSIS_FILE)
    if len(features) > 0 and len(labels) > 0:
        clf, scaler, le = classify(features, labels)
        
        # Save the trained model
        save_model(clf, scaler, le)
        
        # Test with a new file
        test_audio_path = "/kaggle/input/test-data/BP107_Asthma,E W,P L U,59,F.wav"  # Replace with an actual audio file path
        prediction = predict_new_file(clf, scaler, le, test_audio_path)
        print(f"Prediction for {test_audio_path}: {prediction[0]}")
    else:
        print("No valid data processed.")
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Asthma       0.00      0.00      0.00         1
# Bronchiectasis       1.00      0.33      0.50         3
#  Bronchiolitis       0.00      0.00      0.00         3
#           COPD       0.94      0.99      0.96       160
#        Healthy       0.75      0.60      0.67        10
#      Pneumonia       0.20      0.25      0.22         4
#           URTI       0.00      0.00      0.00         3
#
#       accuracy                           0.91       184
#      macro avg       0.41      0.31      0.34       184
#   weighted avg       0.87      0.91      0.89       184
#
# Accuracy: 0.907608695652174
# Model saved to /kaggle/working/lung_disease_model.joblib
# Prediction for /kaggle/input/test-data/BP107_Asthma,E W,P L U,59,F.wav: COPD
